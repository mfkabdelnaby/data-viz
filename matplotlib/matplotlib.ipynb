# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Matplotlib-Tutorial" data-toc-modified-id="Matplotlib-Tutorial-1">Matplotlib Tutorial</a></span><ul class="toc-item"><li><span><a href="#Simple-Plot-(line-plot)" data-toc-modified-id="Simple-Plot-(line-plot)-1.1">Simple Plot (line plot)</a></span></li><li><span><a href="#Plot-Modifications-(Size,-Colors,-Linestyles,-Limits-and-Ticks)" data-toc-modified-id="Plot-Modifications-(Size,-Colors,-Linestyles,-Limits-and-Ticks)-1.2">Plot Modifications (Size, Colors, Linestyles, Limits and Ticks)</a></span></li><li><span><a href="#Plot-Labeling" data-toc-modified-id="Plot-Labeling-1.3">Plot Labeling</a></span></li><li><span><a href="#Legend" data-toc-modified-id="Legend-1.4">Legend</a></span></li><li><span><a href="#Ticks-on-the-x-and-y-axis" data-toc-modified-id="Ticks-on-the-x-and-y-axis-1.5">Ticks on the x and y-axis</a></span></li><li><span><a href="#Scales" data-toc-modified-id="Scales-1.6">Scales</a></span></li><li><span><a href="#Annotations" data-toc-modified-id="Annotations-1.7">Annotations</a></span></li><li><span><a href="#Modifying-Styles" data-toc-modified-id="Modifying-Styles-1.8">Modifying Styles</a></span></li><li><span><a href="#Axes" data-toc-modified-id="Axes-1.9">Axes</a></span><ul class="toc-item"><li><span><a href="#Limiting-Axes" data-toc-modified-id="Limiting-Axes-1.9.1">Limiting Axes</a></span></li><li><span><a href="#Getting-Axis" data-toc-modified-id="Getting-Axis-1.9.2">Getting Axis</a></span></li></ul></li><li><span><a href="#Grid" data-toc-modified-id="Grid-1.10">Grid</a></span></li><li><span><a href="#Removing-the-frame-of-the-Chart" data-toc-modified-id="Removing-the-frame-of-the-Chart-1.11">Removing the frame of the Chart</a></span></li></ul></li><li><span><a href="#Subplots" data-toc-modified-id="Subplots-2">Subplots</a></span><ul class="toc-item"><li><span><a href="#Plot-Figure-on-top-of-the-other" data-toc-modified-id="Plot-Figure-on-top-of-the-other-2.1">Plot Figure on top of the other</a></span></li></ul></li><li><span><a href="#Animation" data-toc-modified-id="Animation-3">Animation</a></span><ul class="toc-item"><li><span><a href="#Plotting-with-Pandas" data-toc-modified-id="Plotting-with-Pandas-3.1">Plotting with Pandas</a></span><ul class="toc-item"><li><span><a href="#DataFrame.plot" data-toc-modified-id="DataFrame.plot-3.1.1">DataFrame.plot</a></span></li><li><span><a href="#pandas.plotting" data-toc-modified-id="pandas.plotting-3.1.2">pandas.plotting</a></span></li></ul></li></ul></li><li><span><a href="#Plotting-2D-Arrays" data-toc-modified-id="Plotting-2D-Arrays-4">Plotting 2D Arrays</a></span><ul class="toc-item"><li><span><a href="#Generating-2D-arrays-using-meshgrid" data-toc-modified-id="Generating-2D-arrays-using-meshgrid-4.1">Generating 2D arrays using meshgrid</a></span><ul class="toc-item"><li><span><a href="#Modifying-colormaps" data-toc-modified-id="Modifying-colormaps-4.1.1">Modifying colormaps</a></span></li><li><span><a href="#2D-Histograms" data-toc-modified-id="2D-Histograms-4.1.2">2D Histograms</a></span></li></ul></li><li><span><a href="#Images" data-toc-modified-id="Images-4.2">Images</a></span><ul class="toc-item"><li><span><a href="#Pseudocolor-plot-from-image-data" data-toc-modified-id="Pseudocolor-plot-from-image-data-4.2.1">Pseudocolor plot from image data</a></span></li><li><span><a href="#Extent-and-aspect" data-toc-modified-id="Extent-and-aspect-4.2.2">Extent and aspect</a></span></li><li><span><a href="#Rescaling-pixel-intensities" data-toc-modified-id="Rescaling-pixel-intensities-4.2.3">Rescaling pixel intensities</a></span></li></ul></li><li><span><a href="#Histogram-equalization-in-images" data-toc-modified-id="Histogram-equalization-in-images-4.3">Histogram equalization in images</a></span><ul class="toc-item"><li><span><a href="#Plot-Histogram-of-an-image" data-toc-modified-id="Plot-Histogram-of-an-image-4.3.1">Plot Histogram of an image</a></span></li><li><span><a href="#Cumulative-Distribution-Function-from-an-image-histogram" data-toc-modified-id="Cumulative-Distribution-Function-from-an-image-histogram-4.3.2">Cumulative Distribution Function from an image histogram</a></span></li><li><span><a href="#Equalizing-an-image-histogram" data-toc-modified-id="Equalizing-an-image-histogram-4.3.3">Equalizing an image histogram</a></span></li><li><span><a href="#Extracting-histograms-from-a-color-image" data-toc-modified-id="Extracting-histograms-from-a-color-image-4.3.4">Extracting histograms from a color image</a></span></li><li><span><a href="#Extracting-bivariate-histograms-from-a-color-image" data-toc-modified-id="Extracting-bivariate-histograms-from-a-color-image-4.3.5">Extracting bivariate histograms from a color image</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Matplotlib Tutorial
#
# **matplotlib** is a module in Python that works with plotting figures

# %% [markdown]
# ## Simple Plot (line plot)
#
# In here a simple sin and cos plots are shown.

# %%
#matlibplot import
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X) #C=cos, S=cos

#print(X) 
#X is now a numpy array with 256 values ranging from -π to +π (included)

plt.plot(X,C) #plot(x-axis, y-axis)
plt.plot(X,S)

plt.show()

# %% [markdown]
# ------
# ## Plot Modifications (Size, Colors, Linestyles, Limits and Ticks)
#
# The following plot parameters are modified:
# * figure size: **`plt.figure`** then set **`figsize`** and **`dpi`**
# * line colors: **`color=`**
# * line widths: **`linewidth=`**
# * linestyle: **`linestyle=`**
# * x & y limits: **`xlim`**
# * x & y ticks & their labels: **`xticks`**
#     * **`rotation=`** to rotate the xticks labels

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

# Create a new figure of size 8x6 points, using 80 dots per inch
plt.figure(figsize=(8,6), dpi=80)
# resolution in dots per inch

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 (pixels)
plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")

# Plot sine using green color with a continuous line of width 1 (pixels)
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

# Set x limits
plt.xlim(-4.5,4.5)

# Set x ticks
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
# to show the important points on the axis

# Set y limits
plt.ylim(-1.1,1.1)

# Set y ticks
plt.yticks([-1, 0, +1],
       [r'$-1$', r'$0$', r'$+1$'])

# Save figure using 72 dots per inch
# savefig("../figures/exercice_2.png",dpi=72)

# Show result on screen
plt.show()

# %% [markdown]
# -------
# ## Plot Labeling
#
# * **`title`**
# * **`xlabel`**
# * **`ylabel`**

# %%
# Plot cosine using blue color with a continuous line of width 1 (pixels)
plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")

# Plot sine using green color with a continuous line of width 1 (pixels)
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

plt.title("Sin and Cos Plot")
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# -----
# ## Legend
#
# First identify:
# * **`lable`** in **`plt.plot`**
#
# Then use:
#
# * **`plt.legend`**
#     * **`loc`**
#     * **`frameon`** bool. defines weather or not to use frame on legend
#
# If the labels are not identified inside `plt.plot` then pass a list of strings inside `plt.legend`
#
# **Legend Locations:** you can use location string or code
#
# | **Location String** | **Location Code** |
# |:-------------------:|:-----------------:|
# |        'best'       |         0         |
# |    'upper right'    |         1         |
# |     'upper left'    |         2         |
# |     'lower left'    |         3         |
# |    'lower right'    |         4         |
# |       'right'       |         5         |
# |    'center left'    |         6         |
# |    'center right'   |         7         |
# |    'lower center'   |         8         |
# | 'upper center'      | 9                 |
# | 'center'            | 10                |

# %%
#label
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine") #label
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="--", label="sine")

#place of the legend is upper left
plt.legend(loc='upper left', frameon=False) #False = no frame

# %% [markdown]
# -------------
#
# ## Ticks on the x and y-axis
#
# * **`xticks`** to specify ticks on axis. First argument defines location (value) on the axis, then the label to be given on the tick
# * **`tick_params`** control which ticks to appear and which to remove

# %%
# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# %% [markdown]
# ------------
# ## Scales
#
# * **`xscale`** to change the scale of the x axis
#     * **`'log'`**
#     * **`'symlog'`**

# %% [markdown]
# -----
# ## Annotations
# * **`plt.annotate()`** to write on a figure
#     * **`s`**: text
#     * **`xy`**: place to annotate at
#     * **`xytext`**: place of text
#     * **`arrowprops`**: arrow properties (color ..)

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C = np.cos(X)

plt.plot(X,C)

# get max of cos
cos_max = C.max()

# value at max cos
x_max = X[C.argmax()]

# add a black arrow pointing at max
plt.annotate('Maximum',xy=(x_max,cos_max),xytext=(x_max+0.3,cos_max+0.3),arrowprops=dict({'facecolor':'black'}))

plt.show()

# %% [markdown]
# -----
# ## Modifying Styles
# * **`plt.style.use()`** to activate a particular stylesheet

# %%
# list all available styles

print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
# use ggplot style
plt.style.use('ggplot')

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C = np.cos(X)

plt.plot(X,C)

# %% [markdown]
# -----
# ## Axes
#
# ### Limiting Axes
# * **`plt.axis()`**
#
# Used to limit x and y axes (similar to `xlim` and `ylim`)
#
# * **`axis([xmin,xmax,ymin,ymax])`**
# * **`axis('off')`** turn off axis lines and labels
# * **`axis('equal')`** forces equal scaling on x and y
# * **`axis('square')`** forces square plot
# * **`axis('tight')`** sets xlim() and ylim() to show all data
#
# * **`plt.twinx()`** to have 2 vertical axes for two different plots
#
# ### Getting Axis
#
# * **`plt.gca()`**
#
# Getting x axis only: `plt.gca().xaxis`

# %% [markdown]
# -----
# ## Grid
# * **`plt.grid`**

# %% [markdown]
# ----------------
# ## Removing the frame of the Chart

# %%
# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# %%
# Turn off some locations of frame
[plt.gca().spines[loc].set_visible(False) for loc in ['top', 'right']]

# %% [markdown]
# ------
# # Subplots
#
# **`plt.subplots(nrows=i,ncol=j, nsubplot)`**
#
# * i rows and j cols. i x j
# * nsubplot is indexed from 1 and refers to figure number row-wise from top left
#
#
# To leave good spacing between the plots:
# * **`plt.tight_layout()`**

# %%
plt.figure()
# subplot with 1 row, 2 columns, and current axis is 1st subplot axes
plt.subplot(1, 2, 1)

linear_data = np.array([1,2,3,4,5,6,7,8])

plt.plot(linear_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
exponential_data = linear_data**2 

# subplot with 1 row, 2 columns, and current axis is 2nd subplot axes
plt.subplot(1, 2, 2)
plt.plot(exponential_data, '-o')

# %% [markdown]
# Notice that y-axis is not fixed between both plots, which shows that the area under the curve for both plots is almost the same!
#
# To do the use **`sharey`** inside the second subplot and pass it the axes of the first subplot

# %%
plt.figure()
ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, '-o')
plt.title('Linear')


# pass sharey=ax1 to ensure the two subplots share the same y axis
ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plt.plot(exponential_data, '-x')
plt.title('Exponential')
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
# Text(0.5, 1.0, 'Exponential')

# %% [markdown]
# **n-by-m matrix subplots with fixed axes**

# %%
# create a 3x3 grid of subplots
fig, ((ax1,ax2,ax3), (ax4,ax5,ax6), (ax7,ax8,ax9)) = plt.subplots(3, 3, sharex=True, sharey=True)
# plot the linear_data on the 5th subplot axes 
ax5.plot(linear_data, '-')
# set title for 5th plot
ax5.set_title('Linear')
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
# Text(0.5, 1.0, 'Linear')

# %% [markdown]
# ## Plot Figure on top of the other

# %%
import pandas as pd
# define the plots
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal': normal_sample, 
                   'random': random_sample, 
                   'gamma': gamma_sample})

plt.figure()
# plot boxplots for all three of df's columns
_ = plt.boxplot([ df['normal'], df['random'], df['gamma'] ], whis='range')
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([ df['normal'], df['random'], df['gamma'] ], whis='range')
# overlay axis on top of another 
ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(x=0.5)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
# switch the y axis ticks for ax2 to the right side
ax2.yaxis.tick_right()

# %% [markdown]
# # Animation
#
# 1. Create a function that defines the steps
# 2. Use: **`animation.FuncAnimation`**
#     * **`internal`** time between movements in ms

# %%
import matplotlib.animation as animation

n = 100
x = np.random.randn(n)

# %%
# create the function that will do the plotting, where curr is the current frame
def update(curr):
    # check if animation is at the last frame, and if so, stop the animation a
    if curr == n: 
        a.event_source.stop()
    plt.cla()
    # note: if bins not int. then the list defines bins edges
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins=bins)
    # put the limits to prevent changing scale each iteration
    plt.axis([-4,4,0,30])
    
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    # [3,27] is the position
    plt.annotate('n = {}'.format(curr), [3,27])

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %% [markdown]
# ------------------------
#
# ## Plotting with Pandas

# %% [markdown]
# ### DataFrame.plot

# %% [markdown]
# To generate n*m array of samples with mean of meu and std of gamma
#
# ```python
# gamma * np.random.randn(n*m) + meu
# ```

# %%
np.random.seed(123)

df = pd.DataFrame({'A': np.random.randn(365), 
                   'B': np.random.randn(365) + 20,
                   'C': np.random.randn(365) - 20}, 
                  index=pd.date_range('1/1/2017', periods=365))
df.head()
# Out:
#                    A          B          C
# 2017-01-01 -1.085631  20.059291 -20.230904
# 2017-01-02  0.997345  21.744041 -16.428421
# 2017-01-03  0.282978  19.032256 -20.396156
# 2017-01-04 -1.506295  20.419568 -20.038321
# 2017-01-05 -0.578600  20.206928 -22.424836

# %%
df.plot(); # add a semi-colon to the end of the plotting call to suppress unwanted output
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %% [markdown]
# We can select which plot we want to use by passing it into the 'kind' parameter.
#
# You can also choose the plot kind by using the `DataFrame.plot.kind` methods instead of providing the `kind` keyword argument.
#
# `kind` :
# - `'line'` : line plot (default)
# - `'bar'` : vertical bar plot
# - `'barh'` : horizontal bar plot
# - `'hist'` : histogram
# - `'box'` : boxplot
# - `'kde'` : Kernel Density Estimation plot
# - `'density'` : same as 'kde'
# - `'area'` : area plot
# - `'pie'` : pie plot
# - `'scatter'` : scatter plot
# - `'hexbin'` : hexbin plot

# %%
df.plot('A','B', kind = 'scatter');
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
# create a scatter plot of columns 'A' and 'C', with changing color (c) and size (s) based on column 'B'
df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
df.plot.box();
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %% [markdown]
# ### pandas.plotting

# %%
pd.plotting.scatter_matrix(df);
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %% [markdown]
# -----------
# # Plotting 2D Arrays
#
# ## Generating 2D arrays using meshgrid
# * **`np.meshgrid`**: Return coordinate matrices from coordinate vectors.
#
#
# You can visualize 2D arrays using:
# * **`plt.pcolor`**
# * **`plt.contour`**
# * **`plt.contourf`** filled contour plots

# %%
# Generate two 1-D arrays: u, v
u = np.linspace(-2, 2, 41)
v = np.linspace(-1, 1, 21)

# Generate 2-D arrays from u and v: X, Y
X,Y = np.meshgrid(u,v)

# Compute Z based on X and Y
Z = np.sin(3*np.sqrt(X**2 + Y**2)) 

# Display the resulting image with pcolor()
plt.pcolor(Z)
plt.show()

# %% [markdown]
# To show the colorbar:
#
# * **`plt.colorbar()`**

# %%
plt.pcolor(Z)
plt.colorbar()
plt.show()

# %% [markdown]
# If you want a black and white plot, use `cmap='gray'` inside `plt.pcolor`
#
# To remove the empty space around the plot:
# * **`plt.axis('tight')`**

# %%
plt.pcolor(Z,cmap='gray')
plt.colorbar()
plt.axis('tight')
plt.show()

# %% [markdown]
# If you include the 1D arrays that shaped the 2D array in the `pcolor` function, the problem of white space is automatically fixed. In addition, the x and y-scales correspond to the coordinates now.

# %%
plt.pcolor(u,v,Z)
plt.colorbar()
plt.show()

# %%
# contour with 30 lines
plt.contour(Z, 30)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Modifying colormaps
# Some examples of colormaps:
# * 'jet' [default],
# * 'coolwarm',
# * 'magma' and
# * 'viridis'
#
# and also:
# * 'Greens',
# * 'Blues',
# * 'Reds', and
# * 'Purples'.

# %% [markdown]
# ### 2D Histograms
#
# * **`plt.hist2d(x,y,bins=(nx,ny))`**
#     * **`range=((xmin, xmax), (ymin, ymax))`** to specify the rectangular limit to plot in
# * **`hexbin()`**: uses hexagonal bins instead of rectangular ones
#     * **`gridsize`** specifies number of hexagons along x and/or y
#     * **`extent=(xmin, xmax, ymin, ymax)`** to specify the rectangular limit to plot in

# %% [markdown]
# ## Images
#
# Images is a matrix of intensity values:
# * **Grayscale images:** rectangular 2D arrays. Black and White images with numbers from 0 to 1 corresponding to black and white, repectively
# * **Color images:** typically three 2D arrays (channels)
#     * **RGB** (Red-Green-Blue)
#     * $M \times N \times 3$. Where $M \times N$ are the dimentions of the image, and the 3rd dimentions are the color channels
#
# Channel values are either:
# * 0 to 1 - floating-point numbers
# * 0 to 255 - 8-bit integers
#
# Loading and Displaying images in python:
# * **`plt.imread()`** to read image files
# * **`plt.imshow()`** to display them

# %%
# Load the image into an array: img
img = plt.imread('Bruce_McCandless_II_during_EVA_in_1984.jpg')

# Print the shape of the image
print(img.shape)

# Display the image
plt.imshow(img)

# Hide the axes
plt.axis('off')
plt.show()
# Out:
# (3072, 3072, 3)

# %% [markdown]
# ### Pseudocolor plot from image data

# %%
# Compute the sum of the red, green and blue channels: intensity
intensity = img.sum(axis=2)

# Print the shape of the intensity
print(intensity.shape)

# Display the intensity with a colormap of 'gray'
plt.imshow(intensity, 'gray')

# Add a colorbar
plt.colorbar()

# Hide the axes and show the figure
plt.axis('off')
plt.show()
# Out:
# (3072, 3072)

# %% [markdown]
# ### Extent and aspect
# The ratio of the displayed width to height is known as the image `aspect` and the range used to label the x- and y-axes is known as the image `extent`. The default `aspect` value of `'auto'` keeps the pixels square and the extents are automatically computed from the shape of the array if not specified otherwise.

# %%
# Load the image into an array: img
img = plt.imread('Bruce_McCandless_II_during_EVA_in_1984.jpg')

# Specify the extent and aspect ratio of the top left subplot
plt.subplot(2,2,1)
plt.title('extent=(-1,1,-1,1),\naspect=0.5') 
plt.xticks([-1,0,1])
plt.yticks([-1,0,1])
plt.imshow(img, extent=(-1,1,-1,1), aspect=0.5)

# Specify the extent and aspect ratio of the top right subplot
plt.subplot(2,2,2)
plt.title('extent=(-1,1,-1,1),\naspect=1')
plt.xticks([-1,0,1])
plt.yticks([-1,0,1])
plt.imshow(img, extent=(-1,1,-1,1), aspect=1)

# Specify the extent and aspect ratio of the bottom left subplot
plt.subplot(2,2,3)
plt.title('extent=(-1,1,-1,1),\naspect=2')
plt.xticks([-1,0,1])
plt.yticks([-1,0,1])
plt.imshow(img, extent=(-1,1,-1,1), aspect=2)

# Specify the extent and aspect ratio of the bottom right subplot
plt.subplot(2,2,4)
plt.title('extent=(-2,2,-1,1),\naspect=2')
plt.xticks([-2,-1,0,1,2])
plt.yticks([-1,0,1])
plt.imshow(img, extent=(-2,2,-1,1), aspect=2)

# Improve spacing and display the figure
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Rescaling pixel intensities
#
# Sometimes, low contrast images can be improved by *rescaling* their intensities.

# %%
# Load the image into an array: image
image = plt.imread('512px-Unequalized_Hawkes_Bay_NZ.jpg')

# Extract minimum and maximum values from the image: pmin, pmax
pmin, pmax = image.min(), image.max()
print("The smallest & largest pixel intensities are %d & %d." % (pmin, pmax))

# Rescale the pixels: rescaled_image
rescaled_image = 256*(image - pmin) / (pmax - pmin)
print("The rescaled smallest & largest pixel intensities are %.1f & %.1f." % 
      (rescaled_image.min(), rescaled_image.max()))

# Display the original image in the top subplot
plt.subplot(2,1,1)
plt.title('original image')
plt.axis('off')
plt.imshow(image,'gray')

# Display the rescaled image in the bottom subplot
plt.subplot(2,1,2)
plt.title('rescaled image')
plt.axis('off')
plt.imshow(rescaled_image,'gray')

plt.show()
# Out:
# The smallest & largest pixel intensities are 102 & 227.
# The rescaled smallest & largest pixel intensities are 0.0 & 256.0.

# %% [markdown]
# ## Histogram equalization in images
#
# ### Plot Histogram of an image

# %%
image = plt.imread('512px-Unequalized_Hawkes_Bay_NZ.jpg')

# Display image in top subplot using color map 'gray'
plt.subplot(2,1,1)
plt.title('Original image')
plt.axis('off')
plt.imshow(image,cmap='gray')

# Flatten the image into 1 dimension: pixels
pixels = image.flatten()

# Display a histogram of the pixels in the bottom subplot
plt.subplot(2,1,2)
plt.xlim((0,255))
plt.title('Normalized histogram')
plt.hist(pixels,bins=64,range=(0,256),density=True,color='red',alpha=0.4)

# Display the plot
plt.show()

# %% [markdown]
# ### Cumulative Distribution Function from an image histogram

# %%
# Load the image into an array: image
image = plt.imread('512px-Unequalized_Hawkes_Bay_NZ.jpg')

# Display image in top subplot using color map 'gray'
plt.subplot(2,1,1)
plt.imshow(image, cmap='gray')
plt.title('Original image')
plt.axis('off')

# Flatten the image into 1 dimension: pixels
pixels = image.flatten()

# Display a histogram of the pixels in the bottom subplot
plt.subplot(2,1,2)
pdf = plt.hist(pixels, bins=64, range=(0,256), 
               normed=False,
               color='red', alpha=0.4)
plt.grid('off')

# Use plt.twinx() to overlay the CDF in the bottom subplot
plt.twinx()

# Display a cumulative histogram of the pixels
cdf = plt.hist(pixels, bins=64, range=(0,256),
               normed=True, cumulative=True,
               color='blue', alpha=0.4)
               
# Specify x-axis range, hide axes, add title and display plot
plt.xlim((0,256))
plt.grid('off')
plt.title('PDF & CDF (original image)')
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %% [markdown]
# ### Equalizing an image histogram
#
# Histogram equalization is an image processing procedure that reassigns image pixel intensities. The basic idea is to use interpolation to map the original CDF of pixel intensities to a CDF that is almost a straight line. In essence, the pixel intensities are spread out and this has the practical effect of making a sharper, contrast-enhanced image.

# %%
# Load the image into an array: image
image = plt.imread('512px-Unequalized_Hawkes_Bay_NZ.jpg')

# Flatten the image into 1 dimension: pixels
pixels = image.flatten()

# Generate a cumulative histogram
cdf, bins, patches = plt.hist(pixels, bins=256, range=(0,256), normed=True, cumulative=True)
new_pixels = np.interp(pixels, bins[:-1], cdf*255)

# Reshape new_pixels as a 2-D array: new_image
new_image = new_pixels.reshape(image.shape)

# Display the new image with 'gray' color map
plt.subplot(2,1,1)
plt.title('Equalized image')
plt.axis('off')
plt.imshow(new_image,cmap='gray')

# Generate a histogram of the new pixels
plt.subplot(2,1,2)
pdf = plt.hist(new_pixels, bins=64, range=(0,256), normed=False,
               color='red', alpha=0.4)
plt.grid('off')

# Use plt.twinx() to overlay the CDF in the bottom subplot
plt.twinx()
plt.xlim((0,256))
plt.grid('off')

# Add title
plt.title('PDF & CDF (equalized image)')

# Generate a cumulative histogram of the new pixels
cdf = plt.hist(new_pixels, bins=64, range=(0,256),
               cumulative=True, normed=True,
               color='blue', alpha=0.4)
plt.show()

# %% [markdown]
# Notice the image is clearer
#
# ### Extracting histograms from a color image

# %%
# Load the image into an array: image
image = plt.imread('hs-2004-32-b-small_web.jpg')

# Display image in top subplot
plt.subplot(2,1,1)
plt.title('Original image')
plt.axis('off')
plt.imshow(image)

# Extract 2-D arrays of the RGB channels: red, blue, green
red, green, blue = image[:,:,0], image[:,:,1], image[:,:,2]

# Flatten the 2-D arrays of the RGB channels into 1-D
red_pixels = red.flatten()
blue_pixels = blue.flatten()
green_pixels = green.flatten()

# Overlay histograms of the pixels of each color in the bottom subplot
plt.subplot(2,1,2)
plt.title('Histograms from color image')
plt.xlim((0,256))
plt.hist(red_pixels, bins=64, normed=True, color='red', alpha=0.2)
plt.hist(blue_pixels, bins=64, normed=True, color='blue', alpha=0.2)
plt.hist(green_pixels, bins=64, normed=True, color='green', alpha=0.2)

# Display the plot
plt.show()

# %% [markdown]
# ### Extracting bivariate histograms from a color image

# %%
# Generate a 2-D histogram of the red and green pixels
plt.subplot(2,2,1)
plt.grid('off') 
plt.xticks(rotation=60)
plt.xlabel('red')
plt.ylabel('green')
plt.hist2d(red_pixels,green_pixels,bins=(32,32))

# Generate a 2-D histogram of the green and blue pixels
plt.subplot(2,2,2)
plt.grid('off')
plt.xticks(rotation=60)
plt.xlabel('green')
plt.ylabel('blue')
plt.hist2d(green_pixels,blue_pixels,bins=(32,32))

# Generate a 2-D histogram of the blue and red pixels
plt.subplot(2,2,3)
plt.grid('off')
plt.xticks(rotation=60)
plt.xlabel('blue')
plt.ylabel('red')
plt.hist2d(blue_pixels,red_pixels,bins=(32,32))

# Display the plot
plt.show()
